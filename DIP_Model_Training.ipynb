# %%
import kagglehub

path = kagglehub.dataset_download("cookiefinder/braille-urdu")
print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 2.22G/2.22G [00:28<00:00, 84.3MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/cookiefinder/braille-urdu/versions/2

# %%
# !apt-get update
# !apt-get install -y liblouis-dev python3-louis
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,616 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,915 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,295 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,004 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
# !rm -rf Grade-1-Urdu-Braille-Detector
# !git clone https://github.com/fez-Ox/Grade-1-Urdu-Braille-Detector.git
# %cd Grade-1-Urdu-Braille-Detector
# !pip install -r requirements.txt
# !cp -r /root/.cache/kagglehub/datasets/cookiefinder/braille-urdu/versions/2 ./inputs/
# Out:
# Cloning into 'Grade-1-Urdu-Braille-Detector'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 70 (delta 16), reused 65 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (70/70), 3.91 MiB | 10.19 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
# /content/Grade-1-Urdu-Braille-Detector/Grade-1-Urdu-Braille-Detector/Grade-1-Urdu-Braille-Detector
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for louis: filename=louis-1.3-py3-none-any.whl size=972 sha256=dadaff90bc95460557f706969f13e374dc8b4b53d4cce0df1c36a97cd3ca224c
#   Stored in directory: /root/.cache/pip/wheels/e3/8a/31/ea8b353bb56e239c3068c22034a22cfd2ea183a463fbd5d445
# Successfully built louis
# ...

# %%
# Training the CNN
# !python cnn/train.py
# Out:
# --- 1. Generating Training Crops ---
# Processed 250/2000 images. Extracted cells: 10998
# Processed 500/2000 images. Extracted cells: 21383
# Processed 750/2000 images. Extracted cells: 32700
# Processed 1000/2000 images. Extracted cells: 44096
# Processed 1250/2000 images. Extracted cells: 55209
# Processed 1500/2000 images. Extracted cells: 66593
# Processed 1750/2000 images. Extracted cells: 79637
# Processed 2000/2000 images. Extracted cells: 90543
#
# Extracted 90543 perfect Braille cell crops from 1401 images.
#
# --- 2. Starting CNN Training ---
# Training on device: cuda
# Epoch 1/15 | Loss: 0.2322 | Acc: 0.9404
# Epoch 2/15 | Loss: 0.0963 | Acc: 0.9697
# Epoch 3/15 | Loss: 0.0860 | Acc: 0.9723
# Epoch 4/15 | Loss: 0.0807 | Acc: 0.9729
# Epoch 5/15 | Loss: 0.0779 | Acc: 0.9733
# Epoch 6/15 | Loss: 0.0736 | Acc: 0.9751
# Epoch 7/15 | Loss: 0.0727 | Acc: 0.9750
# Epoch 8/15 | Loss: 0.0703 | Acc: 0.9754
# Epoch 9/15 | Loss: 0.0688 | Acc: 0.9752
# ...

# %%
# Testing the CNN + Louis Pipeline on an Image
# !python translate_image.py inputs/images/chunk_0003.jpg
# Out:
# Translating image: inputs/images/chunk_0003.jpg
# [ WARN:0@2.477] global loadsave.cpp:278 findDecoder imread_('inputs/images/chunk_0003.jpg'): can't open/read file: check file path/integrity
# Traceback (most recent call last):
#   File "/content/Grade-1-Urdu-Braille-Detector/Grade-1-Urdu-Braille-Detector/Grade-1-Urdu-Braille-Detector/translate_image.py", line 121, in <module>
#     translate_image(img_path)
#   File "/content/Grade-1-Urdu-Braille-Detector/Grade-1-Urdu-Braille-Detector/Grade-1-Urdu-Braille-Detector/translate_image.py", line 64, in translate_image
#     _, _, img_binary = preprocess_img(image_path, temp_dir)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Grade-1-Urdu-Braille-Detector/Grade-1-Urdu-Braille-Detector/Grade-1-Urdu-Braille-Detector/preprocessing/pipeline.py", line 10, in preprocess_img
#     raise FileNotFoundError(f"Could not load image: {image_path}")
# ...

# %%
# For when you make changes to the Repo while an active session
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 359 bytes | 359.00 KiB/s, done.
# From https://github.com/fez-Ox/Grade-1-Urdu-Braille-Detector
#    2e17aea..c82a9d3  main       -> origin/main
# Updating 2e17aea..c82a9d3
# Fast-forward
#  cnn/train.py | 4 ++--
#  1 file changed, 2 insertions(+), 2 deletions(-)
